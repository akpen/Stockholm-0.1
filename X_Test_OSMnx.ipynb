# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import osmnx as ox

# %%
ox.plot_graph(ox.graph_from_place('Bangalore Urban, India', network_type='drive'))
# Out:
# (<matplotlib.figure.Figure at 0x25a56a9c518>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a59ef8550>)

# %%
ox.plot_graph(ox.graph_from_place('Bhimavaram, India', network_type='drive'))
# Out:
# (<matplotlib.figure.Figure at 0x25a17958d68>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a4b722a90>)

# %%
ox.plot_graph(ox.graph_from_place('New York, USA'))
# Out:
# (<matplotlib.figure.Figure at 0x25a028a9908>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a1d13dbe0>)

# %%
#16.323911, 80.865665
G = ox.graph_from_point((16.323911, 80.865665), distance=2000, network_type='all')
ox.plot_graph(G)
# Out:
# (<matplotlib.figure.Figure at 0x25a2fa2d5f8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a1fe95128>)

# %%
ox.plot_graph(ox.graph_from_place('Manhattan, USA'))
# Out:
# (<matplotlib.figure.Figure at 0x25a5349b0f0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a2fb06710>)

# %%
#Domlur
G = ox.graph_from_point((12.960563, 77.641685), distance=800, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a178bfc18>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a7d8614a8>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.0541221016883577

# %%
#23rd Street Manhattan
G = ox.graph_from_point((40.745375, -73.998510), distance=800, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a2f791320>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a0040bac8>)

# %%
#Bayridge
G = ox.graph_from_point((40.619947, -74.031508), distance=800, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a56ccbe10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a55f40d30>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.0120805450769628

# %%
#London
G = ox.graph_from_point((51.510032, -0.135393), distance=800, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a6ed25080>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a2f4b8710>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.0327962111674907

# %%
#Kundalahalli
G = ox.graph_from_point((12.965779, 77.718324), distance=1000, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a727c9f28>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a16095940>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.1415459974656708

# %%
G = ox.graph_from_place('Bhimavaram, India', network_type='drive')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a59666208>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a3a362cc0>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.082888811516245

# %%
#Kukatpally
G = ox.graph_from_point((17.496221, 78.395031), distance=800, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a16017ac8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a5a1b1cf8>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.0315638580749884

# %%
#Kondapur, Hyderabad
G = ox.graph_from_point((17.455301, 78.366294), distance=800, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a3a379828>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a3a38fdd8>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.085966121675718

# %%
#Singapore
G = ox.graph_from_point((1.304390, 103.822744), distance=1200, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a19b41588>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a19b23ef0>)

# %%
stats = ox.basic_stats(G)
stats['circuity_avg']
# Out:
# 1.1141330987810085

# %%
#Beijing
G = ox.graph_from_point((39.907478, 116.363089), distance=1200, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a668989b0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a19f65eb8>)

# %%
#Moscow
G = ox.graph_from_point((55.769716, 37.596565), distance=800, network_type='all')
ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a1555a588>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a59e54ba8>)

# %%
G = ox.graph_from_point((55.769716, 37.596565), distance=800, network_type='all')
culdesacs = [key for key, value in G.graph['streets_per_intersection'].items() if value==1]
nc = ['r' if node in culdesacs else 'none' for node in G.nodes()]
ox.plot_graph(G, node_color=nc)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-85164655cbab> in <module>()
#       1 G = ox.graph_from_point((55.769716, 37.596565), distance=800, network_type='all')
# ----> 2 culdesacs = [key for key, value in G.graph['streets_per_intersection'].items() if value==1]
#       3 nc = ['r' if node in culdesacs else 'none' for node in G.nodes()]
#       4 ox.plot_graph(G, node_color=nc)
#
# KeyError: 'streets_per_intersection'

# %%
G = ox.graph_from_point((12.965779, 77.718324), distance=1000, network_type='drive')
ec = ox.get_edge_colors_by_attr(G, attr='length')
ox.plot_graph(G, edge_color=ec)
# Out:
# (<matplotlib.figure.Figure at 0x25a62d330f0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x25a7c533c50>)

# %%
#G = ox.graph_from_point((12.965779, 77.718324), distance=1000, network_type='all')

place = 'Bangalore Urban, India'
gdf = ox.gdf_from_place(place)
area = ox.project_gdf(gdf).unary_union.area
G = ox.graph_from_place(place, network_type='drive_service')

# %%
# calculate basic and extended network stats, merge them together, and display
stats = ox.basic_stats(G, area=area)
extended_stats = ox.extended_stats(G, ecc=True, bc=True, cc=True)
for key, value in extended_stats.items():
    stats[key] = value
pd.Series(stats)

# %%
G = ox.graph_from_place({'state' : 'Andhra Pradesh'})
ox.plot_graph(G, node_size=0, edge_color=ec)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-e6d6d6468153> in <module>()
#       1 #'state':'Texas'
# ----> 2 G = ox.graph_from_place({'state' : 'Andhra Pradesh'})
#       3 #ec = ['r' if data['oneway'] else 'g' for u, v, key, data in G.edges(keys=True, data=True)]
#       4 ox.plot_graph(G, node_size=0, edge_color=ec)
#
# C:\Program Files\Anaconda3\lib\site-packages\osmnx\osmnx.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery)
#    1815     # create graph using this polygon(s) geometry
#    1816     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
ox.basic_stats(G, area=area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-5ec6182eaa33> in <module>()
# ----> 1 ox.basic_stats(G, area=area)
#
# NameError: name 'area' is not defined
